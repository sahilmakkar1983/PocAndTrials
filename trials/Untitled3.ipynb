# %%
import csv
import pandas as pd
import numpy as np

# %%
'''f = open('/sandbox/sealreports/seal_build_wise_06.csv')
csv_f = csv.reader(f)'''

df1 = pd.read_csv('/sandbox/sealreports/seal_build_wise_06.csv')
df2 = pd.read_csv('/sandbox/shieldreports/seal_beta_build_wise_07.csv')

# %%
'''for row in csv_f:
    print row'''
# Out:
# 'for row in csv_f:\n    print row'

# %%
print df.columns.values
my_df1 = pd.pivot_table(df1,columns=[],index=['BUILD'],values=['categoryC_crash_count','categoryC_tcd_log_days','categoryC_crash_ratio'])
my_df2 = pd.pivot_table(df2,columns=[],index=['BUILD'],values=['categoryC_crash_count','categoryC_tcd_log_days','categoryC_crash_ratio'])
# Out:
# ['BUILD' 'categoryC_crash_count' 'categoryC_tcd_log_days'
#  'categoryC_crash_ratio']

# %%
df11 = pd.DataFrame(df1, columns=['categoryC_crash_count','categoryC_tcd_log_days','categoryC_crash_ratio'])
df22 = pd.DataFrame(df2, columns=['categoryC_crash_count','categoryC_tcd_log_days','categoryC_crash_ratio'])

df11['Key'] = 'categoryC_crash_ratio'
df22['Key'] = 'categoryC_crash_ratio'

DF = pd.concat([df11,df22],keys=['categoryC_crash_ratio','categoryC_crash_ratio'])

DFGroup = DF.groupby(['BUILD','Key'])

DFGPlot = DFGroup.sum().unstack('Key').plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-44-c604fbccf3d9> in <module>()
#       5 df22['Key'] = 'categoryC_crash_ratio'
#       6
# ----> 7 DF = pd.concat([df11,df22],keys=['categoryC_crash_ratio','categoryC_crash_ratio'])
#       8
#       9 DFGroup = DF.groupby(['BUILD','Key'])
#
# /home/tivo/anaconda2/lib/python2.7/site-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     843                        keys=keys, levels=levels, names=names,
#     844                        verify_integrity=verify_integrity,
# --> 845                        copy=copy)
#     846     return op.get_result()
#     847
#
# /home/tivo/anaconda2/lib/python2.7/site-packages/pandas/tools/merge.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
# ...

# %%
'''%matplotlib inline
import matplotlib.pyplot as plt
ax = df[['BUILD','categoryC_crash_ratio']].plot(kind='bar', title ="BuildWise Crash Ratio",figsize=(15,10),legend=True, fontsize=12)
ax.set_xlabel("Builds",fontsize=12)
ax.set_ylabel("Crash Ratio",fontsize=12)
plt.show()'''
# Out:
# '%matplotlib inline\nimport matplotlib.pyplot as plt\nax = df[[\'BUILD\',\'categoryC_crash_ratio\']].plot(kind=\'bar\', title ="BuildWise Crash Ratio",figsize=(15,10),legend=True, fontsize=12)\nax.set_xlabel("Builds",fontsize=12)\nax.set_ylabel("Crash Ratio",fontsize=12)\nplt.show()'

# %%
my_df1['key'] = 'trail1'
my_df2['key'] = 'trail2'

# %%
DF = pd.concat([df1,df2], keys=['categoryC_crash_ratio'])

# %%
DFGroup = DF.groupby(['BUILD','categoryC_crash_ratio'])

# %%
DFGPlot = DFGroup.sum().unstack('categoryC_crash_ratio').plot(kind='bar')
