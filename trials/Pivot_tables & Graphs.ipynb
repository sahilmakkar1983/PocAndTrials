# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
alpha_dataframe = pd.read_csv("/sandbox/sealreports/seal.csv")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
ax = alpha_dataframe[['DATE','crash_ratio']].plot(kind='line', title ="V comp",figsize=(15,10),legend=True, fontsize=12)
ax.set_xlabel("Dates",fontsize=12)
ax.set_ylabel("Crash Ratio",fontsize=12)
plt.show()

# %%
print alpha_dataframe.columns.values
pd.pivot_table(alpha_dataframe,columns=[],index=['DATE'],values=['crash_ratio','tcd_crash_days','tcd_log_days'])
#print alpha_dataframe.columns
# Out:
# ['DATE' 'tcd_crash_days' 'tcd_log_days' 'crash_ratio']
#             crash_ratio  tcd_crash_days  tcd_log_days
# DATE
# 2016-06-05     0.109061               1      9.169190
# 2016-06-06     0.127967               2     15.629028
# 2016-06-07     0.000000               0     13.767593
# 2016-06-08     0.000000               0     18.065509
# 2016-06-09     0.000000               0     16.176782
# 2016-06-10     0.000000               0     20.606458
# 2016-06-11     0.041767               1     23.942569
# 2016-06-12     0.046726               2     42.802303
# 2016-06-13     0.000000               0     52.618414
# 2016-06-14     0.017439               1     57.341169
# 2016-06-15     0.018910               1     52.881921
# 2016-06-16     0.018819               1     53.138912
# 2016-06-17     0.017630               1     56.719919
# 2016-06-18     0.018693               1     53.495417
# 2016-06-19     0.037722               2     53.020012
# ...
